# %%
# 네이버 tv 팟에서 과에서 하이퍼링크(a) 태그의 내용 가져오기
import requests

addr = 'https://tv.naver.com/'
resp = requests.get(addr)
print(resp.text)
# Out:
# ass="blind">재생시간</b>2:37</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12800086" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12800086" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="&#039;열광하는 홈팬들&#039; 전광석화 같은 자비처의 헤더골">&#039;열광하는 홈팬들&#039; 전광석화 같은 자비처의 ..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/champsnv" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="SPOTV_UCL">SPOTV_UCL</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>27,795</span>
# 								<span class="like"><span class="blind">좋아요 수</span>43</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12803779" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200311_114/A0qQU_1583894200586G4tmn_JPEG/20200311_111136_965_1.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="[스페셜] 따뜻한 집이 필요..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>10:45</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12803779" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12803779" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[스페셜] 따뜻한 집이 필요한 우리 해원이.. &#039;사랑과 부러움 사이&#039; #해시태그로_보는_날찾아">[스페셜] 따뜻한 집이 필요한 우리 해원이.. &#039;사랑..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/jtbc.weatherfine" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="날씨가 좋으면 찾아가겠어요">날씨가 좋으면 찾아가겠어요</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>4,769</span>
# 								<span class="like"><span class="blind">좋아요 수</span>146</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12792758" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200310_50/8ebKE_1583831503002z9tGz_JPEG/clip_TS202003100059_20200310175610.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="[미방분] (나름)애교왕 이원..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>3:37</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12792758" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12792758" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[미방분] (나름)애교왕 이원일♥김유진 커플의 알콩달콩 오글달달 카페 데이트 ๑őεő๑">[미방분] (나름)애교왕 이원일♥김유진 커플의 알콩달콩 ..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/mbc.reallovestory" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="부러우면 지는거다">부러우면 지는거다</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>7,942</span>
# 								<span class="like"><span class="blind">좋아요 수</span>26</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12711433" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200305_192/nV2Xx_1583419459365bsIzH_JPEG/1583418814386.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="[문별] Eclipse Log #2 Moon..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>14:16</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12711433" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12711433" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[문별] Eclipse Log #2 Moonstar Day">[문별] Eclipse Log #2 Moonstar Day</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/rbw" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="Rainbowbridge World">Rainbowbridge World</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>167</span>
# 								<span class="like"><span class="blind">좋아요 수</span>12</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12670146" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200303_120/bjweD_1583247525640QyCS3_JPEG/1583247271924.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="르노삼성 XM3 TCe260 (1.3 ..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>24:00</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12670146" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12670146" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="르노삼성 XM3 TCe260 (1.3 터보) 시승기 1부, 말해 뭐합니까? Renault-Samsung XM3 TCe260">르노삼성 XM3 TCe260 (1.3 터보) 시승기 1부, 말해 뭐합..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/nodikar" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="모터리언 Motorian">모터리언 Motorian</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>30,326</span>
# 								<span class="like"><span class="blind">좋아요 수</span>42</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12798902" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200311_210/boY7s_1583856699250GKHgu_JPEG/4a7ccdac-4183-4395-ae83-57da754664e6.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="‘새 친구’ 김형준, 다 같이 ..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>3:48</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12798902" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12798902" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="‘새 친구’ 김형준, 다 같이 함께하는 맛있는 식사시간!">‘새 친구’ 김형준, 다 같이 함께하는 맛있는 식사시간!</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/youngfire" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="불타는 청춘">불타는 청춘</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>39,202</span>
# 								<span class="like"><span class="blind">좋아요 수</span>317</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12788350" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200310_126/kc2BT_1583821907555cK7is_JPEG/20200310_151244_696_1.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="[메이킹] 5G 속도 해원과 임..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>4:18</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12788350" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12788350" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[메이킹] 5G 속도 해원과 임뚝딱 군 &#039;굿나잇 책방&#039; 독서회 비하인드 2편">[메이킹] 5G 속도 해원과 임뚝딱 군 &#039;굿나잇 책방&..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/jtbc.weatherfine" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="날씨가 좋으면 찾아가겠어요">날씨가 좋으면 찾아가겠어요</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>21,014</span>
# 								<span class="like"><span class="blind">좋아요 수</span>391</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12769986" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200309_58/LjuSq_1583738500357UogpI_JPEG/clip_TS202003090039_20200309140605.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="[예능연구소 직캠] IZ*ONE -..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>2:55</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12769986" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12769986" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[예능연구소 직캠] IZ*ONE - SPACESHIP(Choi Yena), 아이즈원 - SPACESHIP(최예나) @Show!MusicCore 20200307">[예능연구소 직캠] IZ*ONE - SPACESHIP(Choi Yena), 아..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/mbc.showmusiccorefancam" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="MBC 예능연구소 직캠">MBC 예능연구소 직캠</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>400</span>
# 								<span class="like"><span class="blind">좋아요 수</span>15</span>
# 							</span>
# 						</li>
#
# 						<li>
# 							<div class="box">
# 								<a class="thumb" href="https://tv.naver.com/v/12765908" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# 									<img src="https://phinf.pstatic.net/tvcast/20200309_136/23iFe_1583727494341jFf9U_JPEG/1583727314029.jpg?type=f194_109_blend" width="194" height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' alt="11년만에 K리그로 돌아온 이..">
# 									<span class="mask"></span>
# 									<em class="time"><b class="blind">재생시간</b>6:24</em>
#
#
#
# 								</a>
# 								<a href="#" class="btn_my _click" data-event="addWatchLater" data-clipno="12765908" data-login="false" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>
# 							</div>
# 							<dl>
# 								<dt>
# 									<a href="https://tv.naver.com/v/12765908" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="11년만에 K리그로 돌아온 이청용, 그 시절 활약 다시보기">11년만에 K리그로 돌아온 이청용, 그 시절 활약 다시보..</tooltip></a>
# 								</dt>
# 								<dd class="cate">
# 									<a href="https://tv.naver.com/talkaboutkleague" onclick="clickcr(this, 'edt.cch', '', '', event)" class="ch"><tooltip title="Talk about K LEAGUE">Talk about K LEAGUE</tooltip></a>
# 								</dd>
# 							</dl>
# 							<span class="info">
# 								<span class="hit"><span class="blind">재생 수</span>17,874</span>
# 								<span class="like"><span class="blind">좋아요 수</span>83</span>
# 							</span>
# 						</li>
#
# 				</ul>
# 			</div>
# 			<!-- //추천 영상 -->
#
# 	</div>
# </div>
# <!-- //container -->
#
#
#
#
#
# <div id="app_creator_studio_layer" class="pl_layer" style="display: none">
# 	<div class="layer_wrap">
# 		<div class="layer_ct">
# 			<div class="layer_pop v3 type2">
#
# 				<div class="layer_box">
# 					<div class="pop_img_area">
# 						<img src="https://ssl.pstatic.net/static/tv/navertv/pc/img/img_main_popup.png" width="400" height="320" border="0" alt="네이버TV에서 동영상을 올려보세요!">
# 					</div>
# 					<p class="txt_notify">이제 누구나 채널을 만들어 동영상을 올릴 수 있어요.</p>
# 					<div class="pop_ui_area">
# 						<span class="pop_chk">
# 							<input type="checkbox" name="" id="pop_chk" class="chb _app_creator_studio_layer_chk">
# 							<label for="pop_chk">다시 보지 않음</label>
# 						</span>
# 					</div>
# 					<div class="btn_area">
# 						<a href="#" class="btn on confirm _click">확인</a>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
#
#
#
# <script type="text/javascript" src='/resources/release/js/jindo.component.LazyLoading_1_10_0.20140220_20200312172050.js'></script>
# <script type="text/javascript" src='/resources/release/js/clickcr_20200312172050.js'></script>
# <script type="text/javascript">
# 	var nsc = "tvcast.recommendation";
# 	var ghtEnv = {
# 		sPageName : "clipEnd",
# 		serviceDomain : "https://tv.naver.com",
# 		mobileDomain : "https://m.tv.naver.com",
# 		apiDomain : "https://api.tv.naver.com",
# 		sRecommendKey : "",
# 		likeItDomain : 'https://common.like.naver.com',
# 		likeItApiDomain : 'https://common.like.naver.com',
# 		rmcSid : "2010",
# 		serviceapiDomainRMC : "https://serviceapi.rmcnmv.naver.com",
# 		isLogin : false
# 	};
#
# 	window.attachEvent ? window.attachEvent('onload', fLoadHandler) : window.addEventListener('load', fLoadHandler, false);
# 	var gJsLibrary = {};
# 	function fLoadHandler() {
# 		var aLoadJs = new Array();
# 		aLoadJs.push('https://ssl.pstatic.net/img.tvcast/pc/js/jindo/jindo.component.1_13_0.20140930.min.js');
# 		aLoadJs.push('/resources/release/js/lcslog_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/clickcr_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/nclk.0.1.8_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/tvcast.Namespace_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/tvcast.pc.Gnb_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/tvcast.pc.MyPage_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/home/tvcast.pc.HomeEventHandler_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/tvcast.pc.PlaylistCookieManager_20200312172050.js');
# 		aLoadJs.push('/resources/release/js/top100/tvcast.pc.AnimateThumb_20200312172050.js');
#
# 		jindo.LazyLoading.load(aLoadJs, function() {
# 			gJsLibrary.homeEventHandler = new HomeEventHandler();
# 			tvcast.pc.Gnb = new Gnb();
# 			MyPage.initEvent();
# 			// 추천영상
# 			tvcast.pc.AnimateThumb.init({"baseEl" : "recommend_rolling"});
# 			// TOP100
# 			tvcast.pc.AnimateThumb.init({"baseEl" : "rank_rolling"});
# 		});
# 		aLoadJs = null;
# 	}
# </script>
#
#
#
#
# <div class="floating_top">
#     <iframe frameborder="0" src="about:blank" style="position:absolute;left:0;top:0;width:100%;height:100%;border:none;vertical-align:bottom" title="TOP"></iframe>
#     <a href="/" class="btn btn_home" onclick="clickcr(this, 'mov.home', '', '', event)" title="홈">홈</a>
#     <a href="#" class="btn btn_top" onclick="goTop();clickcr(this, 'mov.top', '', '', event)" title="TOP">TOP</a>
# </div>
#
# <script>
#     function goTop(){
# 		window.scrollTo(0, 0);
# 		var topEl = document.getElementById('u_skip');
# 		if (topEl) {
# 			topEl.tabIndex = -1;
# 			topEl.focus();
# 			topEl.removeAttribute('tabIndex');
# 		}
#     }
# </script>
#
# </div>
#
#
#
#
#
# <div id="footer" style="padding-left: 180px;">
# <ul>
#     <li class="first"><a href="http://www.naver.com/rules/service.html" target="_blank" onClick="clickcr(this, 'fot.agreement', '', '', event);">이용약관</a></li>
#     <li><a href="http://www.naver.com/rules/privacy.html" target="_blank" onClick="clickcr(this, 'fot.privacy', '', '', event);">개인정보처리방침</a></li>
#     <li><a href="http://www.naver.com/rules/disclaimer.html" target="_blank" onClick="clickcr(this, 'fot.disclaimer', '', '', event);">책임의 한계와 법적고지</a></li>
#     <li><a href="https://help.naver.com/support/alias/navertv/navertv_home-PC.naver" target="_blank" onClick="clickcr(this, 'fot.helpdesk', '', '', event);">네이버TV 고객센터</a></li>
#     <li><a href="https://studio.tv.naver.com/join" target="_blank" onClick="clickcr(this, 'fot.chopen', '', '', event);">채널 만들기</a></li>
#     <li><a href="/n/policy" onClick="clickcr(this, 'fot.policy', '', '', event);">네이버TV 운영정책</a></li>
# </ul>
# <p class="info">본 콘텐츠의 저작권은 저작권자에 있으며, 이를 무단으로 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.</p>
# <address>
#     <a href="http://www.naver.com" class="nhn" target="_blank" onClick="clickcr(this, 'fot.navercorp', '', '', event);">
#         <img src="https://ssl.pstatic.net/static/common/footer/ci_naver.png" width="63" height="11" alt="NAVER">
#     </a>
#     <em>Copyright ©</em>
#     <a href="http://www.navercorp.com" target="_blank" onClick="clickcr(this, 'fot.navercorp', '', '', event);">NAVER Corp.</a>
#     <span>All Rights Reserved.</span>
# </address>
#
# </div>
#
# <div class="dimd" id="layerDimd" style="display:none"></div>
#
# <script type="text/javascript" src="https://ssl.pstatic.net/img.tvcast/mobile/js/splog_m.js"></script>
# <script type="text/javascript">window.BMR.run('https://sp.naver.com/sp');</script>
# <script type="text/javascript">
# 	function redirectMobile() {
# 		setCookie("NTC_PC_MODE", "false");
# 		var sRedirectPcUrl = "";
#
# 		if (location.search === "") {
# 			sRedirectPcUrl = 'https://m.tv.naver.com'+ location.pathname;
# 		} else {
# 			sRedirectPcUrl = 'https://m.tv.naver.com' +
# 							  location.pathname +
# 	        				  location.search.split("&")[0];
# 		}
# 		location.href = sRedirectPcUrl;
# 	}
#
# 	function setCookie(name, value) {
# 		var domain = ".tv.naver.com";
# 		var path = "/";
# 		document.cookie = name + "=" + value + "; path=" + path + "; domain=" + domain;
#     }
#
# 	var TagAZ = {
# 		query: function (obj) {
# 			var q = "";
# 			if (obj) {
# 				q = "?";
# 				for (var key in obj) {
# 					q += key + "=" + obj[key] + "&";
# 				}
# 			}
# 			return q;
# 		},
# 		getPageName: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageName ? ghtEnv.pageName : "";
# 			}
# 			return "";
# 		},
# 		getPageContentsId: function() {
# 			if (typeof ghtEnv !== 'undefined') {
# 				return ghtEnv.pageContentsId ? ghtEnv.pageContentsId : "";
# 			}
# 			return "";
# 		},
# 		url: function(obj) {
# 			if(obj.href) {
# 				return obj.href;
# 			}
# 			return "";
# 		},
# 		send: function (r) {
# 			var sReq =r;
# 			var oImg = new Image();
# 			oImg.src = sReq;
# 		},
# 		tagClickEncoded : function (tagName, pageId, contentId) {
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		tagClick : function(tagName, pageId, contentId) {
# 			tagName = encodeURIComponent(tagName);
# 			TagAZ.clicklog(tagName, pageId, contentId);
# 		},
# 		clicklog : function (tagName, pageId, contentId) {
# 			var obj = {
# 				a : nsc,
# 				c : contentId,
# 				d : location.href,
# 				f : (document.referrer ? document.referrer : ""),
# 				p : pageId,
# 				t : tagName, // tagName
#
# 			}
# 			var q = TagAZ.query(obj);
# 			TagAZ.send("/api/az/nc" + q);
# 		}
# 	};
#
# </script>
# </body>
# </html>

# %%
#html 파싱을 위한 라이브러리 가져오기 
import bs4
#Dom 객체로 만들기 
bs = bs4.BeautifulSoup(resp.text, 'html.parser')
# 선택자를 이용해서 선택 
tvlist = bs.select('li:nth-child(1) > dl > dt > a > tooltip') 

for temp in tvlist : 
    print(temp.getText())
# Out:
# 마스크 7000원 실화? 돈 안들이고 면역력 올리..
# ′최초 공개′ 틴크러시 끝판왕 ′ITZY′의 ′WANNAB..
# [2020.3.11] 10대 TOP10
# “유럽에서 미국 오지 마!”…한국은 제한 해제 검토
# [MV] Glen Check_ Follow The White Rabbit

# %%
# a 태그의 내용 가져오기 
li = bs.find_all('a')
print(li)
# Out:
# ://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_230/KI6a8_1583936504283uwWBl_JPEG/20200311_223938_308_1.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>2:41</em>
# </a>, <a class="btn_my _click" data-clipno="12817844" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12817844" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[진실 혹은 거짓] 코로나19는 날씨가 따뜻해지면 사라진다?">[진실 혹은 거짓] 코로나19는 날씨가 따뜻해지면 사라진..</tooltip></a>, <a class="ch" href="https://tv.naver.com/jtbc.jtbclecture" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="차이나는 클라스">차이나는 클라스</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12514717" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="장난감 고쳐보아요 | 베이비.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200224_138/tvBle_1582526267426a6DRY_JPEG/1582526151460.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>2:49</em>
# </a>, <a class="btn_my _click" data-clipno="12514717" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12514717" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="장난감 고쳐보아요 | 베이비버스 동요">장난감 고쳐보아요 | 베이비버스 동요</tooltip></a>, <a class="ch" href="https://tv.naver.com/babybus" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="베이비버스 인기동요 동화">베이비버스 인기동요 동화</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12656990" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="드라이기 없이 머리빨리 말.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200303_11/8NOAj_15832094773095O74R_JPEG/1583209474209.jpeg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>3:24</em>
# </a>, <a class="btn_my _click" data-clipno="12656990" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12656990" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="드라이기 없이 머리빨리 말리는 꿀팁 ! 3분">드라이기 없이 머리빨리 말리는 꿀팁 ! 3분</tooltip></a>, <a class="ch" href="https://tv.naver.com/hopisophie" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="호피쏘피 바이브">호피쏘피 바이브</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12762004" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[랜선집들이] 인테리어 갑 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200309_130/GOdM5_1583716044964p6CDf_JPEG/23b89649-61a1-11ea-835a-28b4484d608c_01.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>11:59</em>
# </a>, <a class="btn_my _click" data-clipno="12762004" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12762004" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[랜선집들이] 인테리어 갑 홍대 미용실 투어 브이로그 설라온쇼ㅣK beauty salon, SOONSIKI">[랜선집들이] 인테리어 갑 홍대 미용실 투어 브이로그 ..</tooltip></a>, <a class="ch" href="https://tv.naver.com/soonsikihair" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="SOONSIKI">SOONSIKI</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12551087" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="곡예비행사 박쥐 | 박쥐의 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200306_65/JBR7B_1583464531370mtWp4_JPEG/1583464529325.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>5:18</em>
# </a>, <a class="btn_my _click" data-clipno="12551087" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12551087" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="곡예비행사 박쥐 | 박쥐의 특징 | 초음파로 길 찾기 | 자연동화★지니키즈">곡예비행사 박쥐 | 박쥐의 특징 | 초음파로 길 찾기 | ..</tooltip></a>, <a class="ch" href="https://tv.naver.com/genikids" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="지니키즈 (인기 동요・동화・공룡)">지니키즈 (인기 동요・동화・..</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12802206" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[MV] 주니(JUNNY) _ By My S.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_140/OJzG7_1583889762124lqmI8_JPEG/b55cc129-6336-11ea-aea2-505dacfbaa5c_03.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>3:27</em>
# </a>, <a class="btn_my _click" data-clipno="12802206" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12802206" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[MV] 주니(JUNNY) _ By My Side">[MV] 주니(JUNNY) _ By My Side</tooltip></a>, <a class="ch" href="https://tv.naver.com/1thek" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="1theK (원더케이)">1theK (원더케이)</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12721581" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="1주일 다이어트 계획표✔로 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200306_69/7DClq_1583485466339Dr5SJ_PNG/1583485408038.png?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>6:03</em>
# </a>, <a class="btn_my _click" data-clipno="12721581" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12721581" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="1주일 다이어트 계획표✔로 면역력은 올리고, 잉여지방은 줄이고! @식단/운동ㅣ다노티비">1주일 다이어트 계획표✔로 면역력은 올리고, 잉여지방은..</tooltip></a>, <a class="ch" href="https://tv.naver.com/danotv" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="다이어트의 정석 - 다노TV">다이어트의 정석 - 다노TV</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12801771" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[MV] Coda Bridge(코다브릿.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_155/tswmr_1583888191410AMgVl_PNG/1583888121699.png?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>4:06</em>
# </a>, <a class="btn_my _click" data-clipno="12801771" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12801771" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[MV] Coda Bridge(코다브릿지) - How(내가 널 어떻게)">[MV] Coda Bridge(코다브릿지) - How(내가 널 어떻게)</tooltip></a>, <a class="ch" href="https://tv.naver.com/musicnnew" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="MUSIC&amp;NEW">MUSIC&amp;NEW</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12770672" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="도와줘요 마스크맨 | 나쁜 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200309_297/o6TYA_1583740438710vubwP_JPEG/1583740362813.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>3:20</em>
# </a>, <a class="btn_my _click" data-clipno="12770672" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12770672" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="도와줘요 마스크맨 | 나쁜 세균 무찌르자! | 생활습관 놀이 | 지니키즈★티디키즈">도와줘요 마스크맨 | 나쁜 세균 무찌르자! | 생활습관 ..</tooltip></a>, <a class="ch" href="https://tv.naver.com/tidi" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="티디키즈 by 지니키즈">티디키즈 by 지니키즈</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12800086" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="'열광하는 홈팬들'.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_137/rdWAI_15838725100232UD7N_JPEG/20200311_RB_TOT_ISS3.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>2:37</em>
# </a>, <a class="btn_my _click" data-clipno="12800086" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12800086" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="'열광하는 홈팬들' 전광석화 같은 자비처의 헤더골">'열광하는 홈팬들' 전광석화 같은 자비처의 ..</tooltip></a>, <a class="ch" href="https://tv.naver.com/champsnv" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="SPOTV_UCL">SPOTV_UCL</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12803779" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[스페셜] 따뜻한 집이 필요.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_114/A0qQU_1583894200586G4tmn_JPEG/20200311_111136_965_1.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>10:45</em>
# </a>, <a class="btn_my _click" data-clipno="12803779" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12803779" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[스페셜] 따뜻한 집이 필요한 우리 해원이.. '사랑과 부러움 사이' #해시태그로_보는_날찾아">[스페셜] 따뜻한 집이 필요한 우리 해원이.. '사랑..</tooltip></a>, <a class="ch" href="https://tv.naver.com/jtbc.weatherfine" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="날씨가 좋으면 찾아가겠어요">날씨가 좋으면 찾아가겠어요</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12792758" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[미방분] (나름)애교왕 이원.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200310_50/8ebKE_1583831503002z9tGz_JPEG/clip_TS202003100059_20200310175610.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>3:37</em>
# </a>, <a class="btn_my _click" data-clipno="12792758" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12792758" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[미방분] (나름)애교왕 이원일♥김유진 커플의 알콩달콩 오글달달 카페 데이트 ๑őεő๑">[미방분] (나름)애교왕 이원일♥김유진 커플의 알콩달콩 ..</tooltip></a>, <a class="ch" href="https://tv.naver.com/mbc.reallovestory" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="부러우면 지는거다">부러우면 지는거다</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12711433" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[문별] Eclipse Log #2 Moon.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200305_192/nV2Xx_1583419459365bsIzH_JPEG/1583418814386.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>14:16</em>
# </a>, <a class="btn_my _click" data-clipno="12711433" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12711433" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[문별] Eclipse Log #2 Moonstar Day">[문별] Eclipse Log #2 Moonstar Day</tooltip></a>, <a class="ch" href="https://tv.naver.com/rbw" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="Rainbowbridge World">Rainbowbridge World</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12670146" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="르노삼성 XM3 TCe260 (1.3 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200303_120/bjweD_1583247525640QyCS3_JPEG/1583247271924.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>24:00</em>
# </a>, <a class="btn_my _click" data-clipno="12670146" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12670146" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="르노삼성 XM3 TCe260 (1.3 터보) 시승기 1부, 말해 뭐합니까? Renault-Samsung XM3 TCe260">르노삼성 XM3 TCe260 (1.3 터보) 시승기 1부, 말해 뭐합..</tooltip></a>, <a class="ch" href="https://tv.naver.com/nodikar" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="모터리언 Motorian">모터리언 Motorian</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12798902" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="‘새 친구’ 김형준, 다 같이 .." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200311_210/boY7s_1583856699250GKHgu_JPEG/4a7ccdac-4183-4395-ae83-57da754664e6.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>3:48</em>
# </a>, <a class="btn_my _click" data-clipno="12798902" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12798902" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="‘새 친구’ 김형준, 다 같이 함께하는 맛있는 식사시간!">‘새 친구’ 김형준, 다 같이 함께하는 맛있는 식사시간!</tooltip></a>, <a class="ch" href="https://tv.naver.com/youngfire" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="불타는 청춘">불타는 청춘</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12788350" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[메이킹] 5G 속도 해원과 임.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200310_126/kc2BT_1583821907555cK7is_JPEG/20200310_151244_696_1.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>4:18</em>
# </a>, <a class="btn_my _click" data-clipno="12788350" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12788350" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[메이킹] 5G 속도 해원과 임뚝딱 군 '굿나잇 책방' 독서회 비하인드 2편">[메이킹] 5G 속도 해원과 임뚝딱 군 '굿나잇 책방&amp;..</tooltip></a>, <a class="ch" href="https://tv.naver.com/jtbc.weatherfine" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="날씨가 좋으면 찾아가겠어요">날씨가 좋으면 찾아가겠어요</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12769986" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="[예능연구소 직캠] IZ*ONE -.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200309_58/LjuSq_1583738500357UogpI_JPEG/clip_TS202003090039_20200309140605.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>2:55</em>
# </a>, <a class="btn_my _click" data-clipno="12769986" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12769986" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="[예능연구소 직캠] IZ*ONE - SPACESHIP(Choi Yena), 아이즈원 - SPACESHIP(최예나) @Show!MusicCore 20200307">[예능연구소 직캠] IZ*ONE - SPACESHIP(Choi Yena), 아..</tooltip></a>, <a class="ch" href="https://tv.naver.com/mbc.showmusiccorefancam" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="MBC 예능연구소 직캠">MBC 예능연구소 직캠</tooltip></a>, <a class="thumb" href="https://tv.naver.com/v/12765908" onclick="clickcr(this, 'edt.cthm', '', '', event)">
# <img alt="11년만에 K리그로 돌아온 이.." height="109" onerror='this.src="https://phinf.pstatic.net/tvcast/20161227_263/photoinfra_1482831787654EeESz_PNG/default_clip.png?type=f194_109"' src="https://phinf.pstatic.net/tvcast/20200309_136/23iFe_1583727494341jFf9U_JPEG/1583727314029.jpg?type=f194_109_blend" width="194"/>
# <span class="mask"></span>
# <em class="time"><b class="blind">재생시간</b>6:24</em>
# </a>, <a class="btn_my _click" data-clipno="12765908" data-event="addWatchLater" data-login="false" href="#" onclick="clickcr(this, 'edt.add', '', '', event);">나중에 보기</a>, <a href="https://tv.naver.com/v/12765908" onclick="clickcr(this, 'edt.ctitle', '', '', event)"><tooltip title="11년만에 K리그로 돌아온 이청용, 그 시절 활약 다시보기">11년만에 K리그로 돌아온 이청용, 그 시절 활약 다시보..</tooltip></a>, <a class="ch" href="https://tv.naver.com/talkaboutkleague" onclick="clickcr(this, 'edt.cch', '', '', event)"><tooltip title="Talk about K LEAGUE">Talk about K LEAGUE</tooltip></a>, <a class="btn on confirm _click" href="#">확인</a>, <a class="btn btn_home" href="/" onclick="clickcr(this, 'mov.home', '', '', event)" title="홈">홈</a>, <a class="btn btn_top" href="#" onclick="goTop();clickcr(this, 'mov.top', '', '', event)" title="TOP">TOP</a>, <a href="http://www.naver.com/rules/service.html" onclick="clickcr(this, 'fot.agreement', '', '', event);" target="_blank">이용약관</a>, <a href="http://www.naver.com/rules/privacy.html" onclick="clickcr(this, 'fot.privacy', '', '', event);" target="_blank">개인정보처리방침</a>, <a href="http://www.naver.com/rules/disclaimer.html" onclick="clickcr(this, 'fot.disclaimer', '', '', event);" target="_blank">책임의 한계와 법적고지</a>, <a href="https://help.naver.com/support/alias/navertv/navertv_home-PC.naver" onclick="clickcr(this, 'fot.helpdesk', '', '', event);" target="_blank">네이버TV 고객센터</a>, <a href="https://studio.tv.naver.com/join" onclick="clickcr(this, 'fot.chopen', '', '', event);" target="_blank">채널 만들기</a>, <a href="/n/policy" onclick="clickcr(this, 'fot.policy', '', '', event);">네이버TV 운영정책</a>, <a class="nhn" href="http://www.naver.com" onclick="clickcr(this, 'fot.navercorp', '', '', event);" target="_blank">
# <img alt="NAVER" height="11" src="https://ssl.pstatic.net/static/common/footer/ci_naver.png" width="63"/>
# </a>, <a href="http://www.navercorp.com" onclick="clickcr(this, 'fot.navercorp', '', '', event);" target="_blank">NAVER Corp.</a>]

# %%
# 정규식 (문자열 패턴을 조회하기 위한 식) 모듈 import
import re

for temp in li : 
    print(temp.getText()) # 태그안의 내용 가져오기 
    print(temp.attrs['href'])  #key 에러 - href 가 없는 경우도 있음 
    if 'href' in temp.attrs :   #href 속성이 temp.attrs에 있는 경우에만 
        #href 속성에 /wiki/ 로 시작하는 링크의 텍스트와 링크만 출력 
        href = temp.attrs['href']
        # 정규식 생성 - /wiki/ 로 시작하는 
        p = re.compile('^(/wiki/)')
        if p.search(href) != None : 
            print(temp.getText(), ":", href)
# Out:
# mare' 무..
# https://tv.naver.com/v/12835866/list/67096
# M COUNTDOWN
# https://tv.naver.com/mcountdown
#
#
#
# 재생시간2:29
#
# https://tv.naver.com/v/12835495/list/67096
# 나중에 보기
# #
# 세 번째 '대유행'…계절성 유행병 될 수도
# https://tv.naver.com/v/12835495/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간1:18
#
# https://tv.naver.com/v/12713069/list/67096
# 나중에 보기
# #
# 당신의 손에서 진이 탄생합니다_미스터트롯 11..
# https://tv.naver.com/v/12713069/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간4:37
#
# https://tv.naver.com/v/12584114/list/67096
# 나중에 보기
# #
# 임영웅 ‘보라빛 엽서’♩ 심금을 울리는 목소리 ˘..
# https://tv.naver.com/v/12584114/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간1:36
#
# https://tv.naver.com/v/12835838/list/67096
# 나중에 보기
# #
# 텅 빈 거리, "불안·좌절 드리워져"…봉쇄 '뉴로..
# https://tv.naver.com/v/12835838/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간1:52
#
# https://tv.naver.com/v/12834617/list/67096
# 나중에 보기
# #
# 슈퍼맨이 돌아왔다 321회 티저 - 강부자네
# https://tv.naver.com/v/12834617/list/67096
# 슈퍼맨이 돌아왔다
# https://tv.naver.com/superman
#
#
#
# 재생시간10:45
#
# https://tv.naver.com/v/12779204/list/67096
# 나중에 보기
# #
# [현지반응] '주전 도약' 이승우, 벨기에 언론 ..
# https://tv.naver.com/v/12779204/list/67096
# 서형욱의 뽈리TV
# https://tv.naver.com/footballist
#
#
#
# 재생시간1:53
#
# https://tv.naver.com/v/12836800/list/67096
# 나중에 보기
# #
# 대구시-경찰, 신천지 교회 진입…200명 투입 ‘행..
# https://tv.naver.com/v/12836800/list/67096
# 채널A뉴스
# https://tv.naver.com/channelanews
#
#
#
# 재생시간2:09
#
# https://tv.naver.com/v/12835394/list/67096
# 나중에 보기
# #
# 대서양 막은 트럼프…"유럽에서 미국 못 온다"
# https://tv.naver.com/v/12835394/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간2:36
#
# https://tv.naver.com/v/12836041/list/67096
# 나중에 보기
# #
# ＂복수하러 들어온 거지!?＂ 오채이 언니 차예련 ..
# https://tv.naver.com/v/12836041/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간7:01
#
# https://tv.naver.com/v/12835790/list/67096
# 나중에 보기
# #
# [섹션뉴스] 현금 주는 ‘재난 기본소득’…도입 급..
# https://tv.naver.com/v/12835790/list/67096
# KBS뉴스
# https://tv.naver.com/kbsnews
#
#
#
# 재생시간3:21
#
# https://tv.naver.com/v/12817924/list/67096
# 나중에 보기
# #
# [고막남친♥] 정용화, 선배님들을 위한 즉흥무대..
# https://tv.naver.com/v/12817924/list/67096
# 트롯신이 떴다
# https://tv.naver.com/sbs.trotgod
#
#
#
# 재생시간2:32
#
# https://tv.naver.com/v/12836032/list/67096
# 나중에 보기
# #
# 왜 언론은 세계의 칭찬에 주목하지 않을까?
# https://tv.naver.com/v/12836032/list/67096
# 뉴스는 YTN
# https://tv.naver.com/ytnnews24
#
#
#
# 재생시간6:26
#
# https://tv.naver.com/v/12817109/list/67096
# 나중에 보기
# #
# '왜 꼭 엄마가 가야 해?' 담담해서 더욱 먹먹한..
# https://tv.naver.com/v/12817109/list/67096
# 유 퀴즈 온 더 블럭
# https://tv.naver.com/cjenm.youquizontheblock
#
#
#
# 재생시간5:56
#
# https://tv.naver.com/v/12704334/list/67096
# 나중에 보기
# #
# 《스페셜》 시대를 앞서간 천재 아티스트! 연예인..
# https://tv.naver.com/v/12704334/list/67096
# 라디오스타
# https://tv.naver.com/radiostar
#
#
#
# 재생시간4:19
#
# https://tv.naver.com/v/12711899/list/67096
# 나중에 보기
# #
# ✲깜찍·귀염·잘생김✲ 정동원 vs 장민호 ‘파트너’..
# https://tv.naver.com/v/12711899/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간10:09
#
# https://tv.naver.com/v/12771866/list/67096
# 나중에 보기
# #
# 강남 아파트 호가 벌써 6억 추락…6월 이후 폭락..
# https://tv.naver.com/v/12771866/list/67096
# 땅집고TV
# https://tv.naver.com/realtygo2017
#
#
#
# 재생시간1:45
#
# https://tv.naver.com/v/12836170/list/67096
# 나중에 보기
# #
# '팬데믹 선언'에 세계 증시 쇼크…코스피 '사이..
# https://tv.naver.com/v/12836170/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간2:46
#
# https://tv.naver.com/v/12816964/list/67096
# 나중에 보기
# #
# 임관하자마자 대구로 파견된 간호장교의 각오
# https://tv.naver.com/v/12816964/list/67096
# 유 퀴즈 온 더 블럭
# https://tv.naver.com/cjenm.youquizontheblock
#
#
#
# 재생시간1:37
#
# https://tv.naver.com/v/12835720/list/67096
# 나중에 보기
# #
# 차예련 남편 김흥수 설득에도... ＂이건 사기결..
# https://tv.naver.com/v/12835720/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간2:45
#
# https://tv.naver.com/v/12836293/list/67096
# 나중에 보기
# #
# ＂네게 면목이 없어＂ 아들 김흥수에 용서 구하는..
# https://tv.naver.com/v/12836293/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간2:49
#
# https://tv.naver.com/v/12836295/list/67096
# 나중에 보기
# #
# 최명길 아픈 차예련에 걱정 ↑ ＂내 딸이기도 해!..
# https://tv.naver.com/v/12836295/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간5:16
#
# https://tv.naver.com/v/12711343/list/67096
# 나중에 보기
# #
# 류지광vs김호중 ‘다시 한번만’♪ 동굴과 천상의 ..
# https://tv.naver.com/v/12711343/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간2:12
#
# https://tv.naver.com/v/12835196/list/67096
# 나중에 보기
# #
# "여행 제한도 풀 수 있다"…한국 뺀 이유는?
# https://tv.naver.com/v/12835196/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간2:22
#
# https://tv.naver.com/v/12836401/list/67096
# 나중에 보기
# #
# 배운대로 복수하는 차예련♨ ＂친자식에게 칼 맞..
# https://tv.naver.com/v/12836401/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간1:00
#
# https://tv.naver.com/v/12652325/list/67096
# 나중에 보기
# #
# 3월, 채널A 로맨틱 캔버스가 찾아옵니다.
# https://tv.naver.com/v/12652325/list/67096
# 하트시그널 시즌3
# https://tv.naver.com/channela.heartsignal3
#
#
#
# 재생시간1:38
#
# https://tv.naver.com/v/12837559/list/67096
# 나중에 보기
# #
# '꼭 살립시다' 위기의 환자를 구하러 온 다스베..
# https://tv.naver.com/v/12837559/list/67096
# 슬기로운 의사생활
# https://tv.naver.com/cjenm.doctorlife
#
#
#
# 재생시간2:09
#
# https://tv.naver.com/v/12835283/list/67096
# 나중에 보기
# #
# 갑자기 "입국 차단"에 유럽 국가 '반발'
# https://tv.naver.com/v/12835283/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간1:57
#
# https://tv.naver.com/v/12836184/list/67096
# 나중에 보기
# #
# 어느 곳도 편하지 않는 차예련...
# https://tv.naver.com/v/12836184/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간4:55
#
# https://tv.naver.com/v/12711177/list/67096
# 나중에 보기
# #
# 이찬원 vs 나태주 ‘남자다잉’♩ 춤 좀 춘다잉? ..
# https://tv.naver.com/v/12711177/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간2:00
#
# https://tv.naver.com/v/12835534/list/67096
# 나중에 보기
# #
# 갑자기 '대국민 연설'…초강수 배경은?
# https://tv.naver.com/v/12835534/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간6:18
#
# https://tv.naver.com/v/12834751/list/67096
# 나중에 보기
# #
# [코다리] 리얼 꽁냥꽁냥 케미가 넘친다! / 여자..
# https://tv.naver.com/v/12834751/list/67096
# KOVO (V-LEAGUE)
# https://tv.naver.com/kovo
#
#
#
# 재생시간3:26
#
# https://tv.naver.com/v/12835692/list/67096
# 나중에 보기
# #
# '1위' 완성형 카리스마 '이달의 소녀'의 'So Wh..
# https://tv.naver.com/v/12835692/list/67096
# M COUNTDOWN
# https://tv.naver.com/mcountdown
#
#
#
# 재생시간2:21
#
# https://tv.naver.com/v/12835496/list/67096
# 나중에 보기
# #
# 문 잠그는 지구촌…경제도 줄줄이 '도미노'
# https://tv.naver.com/v/12835496/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간3:42
#
# https://tv.naver.com/v/12822613/list/67096
# 나중에 보기
# #
# [♡새로이&이서캠♡] 새로이서의 맴찢 고백 연기 ..
# https://tv.naver.com/v/12822613/list/67096
# 이태원 클라쓰
# https://tv.naver.com/jtbc.itaewonclass
#
#
#
# 재생시간1:54
#
# https://tv.naver.com/v/77248/list/67096
# 나중에 보기
# #
# 김지선, 가족 여행에서 부부사랑 몰래 나누는 ..
# https://tv.naver.com/v/77248/list/67096
# 웰컴 투 시월드
# https://tv.naver.com/shiworld
#
#
#
# 재생시간2:05
#
# https://tv.naver.com/v/12835717/list/67096
# 나중에 보기
# #
# 숨어있는 최명길에 차예련 분노♨ ＂다신 나타나..
# https://tv.naver.com/v/12835717/list/67096
# 우아한 모녀
# https://tv.naver.com/kbs.revenge
#
#
#
# 재생시간5:40
#
# https://tv.naver.com/v/12463458/list/67096
# 나중에 보기
# #
# 임영웅 ‘어느 60대 노부부 이야기’♩ 첫 소절에 ..
# https://tv.naver.com/v/12463458/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간7:29
#
# https://tv.naver.com/v/12827503/list/67096
# 나중에 보기
# #
# [후토크] 2000년생 묶고 신난 빠리 형들, 승리 ..
# https://tv.naver.com/v/12827503/list/67096
# 서형욱의 뽈리TV
# https://tv.naver.com/footballist
#
#
#
# 재생시간4:16
#
# https://tv.naver.com/v/12712914/list/67096
# 나중에 보기
# #
# ☞충격의 1위☜ 임영웅! 최후의 7위는? 대박..
# https://tv.naver.com/v/12712914/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간1:45
#
# https://tv.naver.com/v/12836309/list/67096
# 나중에 보기
# #
# 기둥 들이받고 두 동강…20대 3명 사망
# https://tv.naver.com/v/12836309/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간0:45
#
# https://tv.naver.com/v/12809731/list/67096
# 나중에 보기
# #
# [2차 티저] 이민호×김고은, 그리고 김은숙 작가..
# https://tv.naver.com/v/12809731/list/67096
# 더킹: 영원의 군주
# https://tv.naver.com/sbs.theking
#
#
#
# 재생시간14:27
#
# https://tv.naver.com/v/12800630/list/67096
# 나중에 보기
# #
# 발렌시아 vs 아탈란타 경기 하이라이트
# https://tv.naver.com/v/12800630/list/67096
# SPOTV_UCL
# https://tv.naver.com/champsnv
#
#
#
# 재생시간2:06
#
# https://tv.naver.com/v/12834243/list/67096
# 나중에 보기
# #
# "교회에서 옮은 뒤 PC방으로"...또 집단감염 나..
# https://tv.naver.com/v/12834243/list/67096
# 뉴스는 YTN
# https://tv.naver.com/ytnnews24
#
#
#
# 재생시간1:57
#
# https://tv.naver.com/v/12836768/list/67096
# 나중에 보기
# #
# 손정의 “무료 키트 100만 개 제공”…日 네티즌 ..
# https://tv.naver.com/v/12836768/list/67096
# 채널A뉴스
# https://tv.naver.com/channelanews
#
#
#
# 재생시간1:46
#
# https://tv.naver.com/v/12757321/list/67096
# 나중에 보기
# #
# 말이 서툴러 슬픈 벤틀리, 억울해!
# https://tv.naver.com/v/12757321/list/67096
# 슈퍼맨이 돌아왔다
# https://tv.naver.com/superman
#
#
#
# 재생시간2:20
#
# https://tv.naver.com/v/12818179/list/67096
# 나중에 보기
# #
# “누나 한번 믿어봐~♬” 홍진영, 야채곱창집에 뜬..
# https://tv.naver.com/v/12818179/list/67096
# 백종원의 골목식당
# https://tv.naver.com/sbs.street
#
#
#
# 재생시간3:11
#
# https://tv.naver.com/v/12837483/list/67096
# 나중에 보기
# #
# 본업 완벽★신경외과 전미도, 뇌물은 칼같이, 위..
# https://tv.naver.com/v/12837483/list/67096
# 슬기로운 의사생활
# https://tv.naver.com/cjenm.doctorlife
#
#
#
# 재생시간3:54
#
# https://tv.naver.com/v/12816466/list/67096
# 나중에 보기
# #
# [풀버전] 장윤정을 울컥하게 만든 버스킹 ♬초혼..
# https://tv.naver.com/v/12816466/list/67096
# 트롯신이 떴다
# https://tv.naver.com/sbs.trotgod
#
#
#
# 재생시간1:22
#
# https://tv.naver.com/v/12822775/list/67096
# 나중에 보기
# #
# [631회 선공개] 왕년에 군기반장 노사연 잡았던..
# https://tv.naver.com/v/12822775/list/67096
# 해피 투게더 4
# https://tv.naver.com/happytogether3
#
#
#
# 재생시간1:20
#
# https://tv.naver.com/v/12836960/list/67096
# 나중에 보기
# #
# 대구 신천지 교육생, 자가격리 이탈해 진주 이..
# https://tv.naver.com/v/12836960/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간3:21
#
# https://tv.naver.com/v/12818945/list/67096
# 나중에 보기
# #
# “냄새도 못 맡았어요” 김성주, 드디어 바라던 ..
# https://tv.naver.com/v/12818945/list/67096
# 백종원의 골목식당
# https://tv.naver.com/sbs.street
#
#
#
# 재생시간2:16
#
# https://tv.naver.com/v/12836503/list/67096
# 나중에 보기
# #
# 114개국·12만 명 나오자 이제야 "세계적 대유행..
# https://tv.naver.com/v/12836503/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간1:56
#
# https://tv.naver.com/v/12836216/list/67096
# 나중에 보기
# #
# 구로 콜센터 관련 확진 100명 넘어…다른 층도 2..
# https://tv.naver.com/v/12836216/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간3:00
#
# https://tv.naver.com/v/12836704/list/67096
# 나중에 보기
# #
# '콜센터 확진자' 예배 봤던 교회서 4명 확진…2..
# https://tv.naver.com/v/12836704/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간4:53
#
# https://tv.naver.com/v/12817108/list/67096
# 나중에 보기
# #
# 코로나19 확진자 진료 책임자 자기님이 말하는 ..
# https://tv.naver.com/v/12817108/list/67096
# 유 퀴즈 온 더 블럭
# https://tv.naver.com/cjenm.youquizontheblock
#
#
#
# 재생시간0:38
#
# https://tv.naver.com/v/12394353/list/67096
# 나중에 보기
# #
# ＂달달한 썸은 일단 삼키고 보는 거야” ＜하트시..
# https://tv.naver.com/v/12394353/list/67096
# 하트시그널 시즌3
# https://tv.naver.com/channela.heartsignal3
#
#
#
# 재생시간4:09
#
# https://tv.naver.com/v/12712637/list/67096
# 나중에 보기
# #
# ※심쿵주의보※ 영탁 vs 신인선 ‘또 만났네요’♭
# https://tv.naver.com/v/12712637/list/67096
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
# 재생시간23:14
#
# https://tv.naver.com/v/12835371/list/67096
# 나중에 보기
# #
# 유벤투스 루가니 확진, 챔스 유로파 시즌 못 끝..
# https://tv.naver.com/v/12835371/list/67096
# 달수네라이브
# https://tv.naver.com/dalsu
#
#
#
# 재생시간1:37
#
# https://tv.naver.com/v/12826380/list/67096
# 나중에 보기
# #
# 추한 클롭, 동양인 팬에게 인종차별 욕설 논란...
# https://tv.naver.com/v/12826380/list/67096
# 스포탈TV
# https://tv.naver.com/sportalkoreatv
#
#
#
# 재생시간2:40
#
# https://tv.naver.com/v/12835401/list/67096
# 나중에 보기
# #
# 전례없는 이동 제한…"예측도 어렵다"
# https://tv.naver.com/v/12835401/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간2:28
#
# https://tv.naver.com/v/12837324/list/67096
# 나중에 보기
# #
# "조선유치원에는 안 줍니다"...아이들 건강도 ..
# https://tv.naver.com/v/12837324/list/67096
# 뉴스는 YTN
# https://tv.naver.com/ytnnews24
#
#
#
# 재생시간1:34
#
# https://tv.naver.com/v/12837462/list/67096
# 나중에 보기
# #
# 사람 먹을 돼지고기를 쓰레기차로 운반…들끓는 ..
# https://tv.naver.com/v/12837462/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간2:54
#
# https://tv.naver.com/v/12756134/list/67096
# 나중에 보기
# #
# 태태브라더스 아메리칸 블랙퍼스트 (feat. 엄근..
# https://tv.naver.com/v/12756134/list/67096
# 슈퍼맨이 돌아왔다
# https://tv.naver.com/superman
#
#
#
# 재생시간1:48
#
# https://tv.naver.com/v/12836747/list/67096
# 나중에 보기
# #
# 트럼프의 결단, 대서양 차단했다…“영국 빼고 오..
# https://tv.naver.com/v/12836747/list/67096
# 채널A뉴스
# https://tv.naver.com/channelanews
#
#
#
# 재생시간1:27
#
# https://tv.naver.com/v/12836005/list/67096
# 나중에 보기
# #
# 잇단 유럽발 감염에…프랑스 등 5개국 '특별입국..
# https://tv.naver.com/v/12836005/list/67096
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
# 재생시간1:33
#
# https://tv.naver.com/v/12836837/list/67096
# 나중에 보기
# #
# "심장 찌르는 듯한 통증"…코로나19 완치자에게 ..
# https://tv.naver.com/v/12836837/list/67096
# MBN 뉴스
# https://tv.naver.com/mbnnews
#
#
#
# 재생시간2:19
#
# https://tv.naver.com/v/12835568/list/67096
# 나중에 보기
# #
# '콜센터' 확진 1백 명 넘어…가족·친척도 감염
# https://tv.naver.com/v/12835568/list/67096
# MBC뉴스
# https://tv.naver.com/imnews
#
#
#
# 재생시간7:10
#
# https://tv.naver.com/v/12821064/list/67096
# 나중에 보기
# #
# 포수 잰슨 "류현진은 눈높이 선생님" | 김형준
# https://tv.naver.com/v/12821064/list/67096
# 김형준의 인사이드MLB
# https://tv.naver.com/insidemlb
#
#
#
# 재생시간2:08
#
# https://tv.naver.com/v/12836492/list/67096
# 나중에 보기
# #
# 문소리의 비밀 연애! 그 이유는??
# https://tv.naver.com/v/12836492/list/67096
# 밥블레스유2
# https://tv.naver.com/cjenm.bobblessyou2
#
#
#
# 재생시간2:52
#
# https://tv.naver.com/v/12816710/list/67096
# 나중에 보기
# #
# (눈물주의) 코로나19로 아이들과 마지막 인사조..
# https://tv.naver.com/v/12816710/list/67096
# 유 퀴즈 온 더 블럭
# https://tv.naver.com/cjenm.youquizontheblock
#
#
#
# 재생시간10:53
#
# https://tv.naver.com/v/12820106/list/67096
# 나중에 보기
# #
# 토론토에서 가장 늦게 퇴근하는 선수는? 어느 ..
# https://tv.naver.com/v/12820106/list/67096
# DKTV
# https://tv.naver.com/dktv
#
#
#
# 재생시간11:15
#
# https://tv.naver.com/v/12834372/list/67096
# 나중에 보기
# #
# 송광민이 푸는 정우람 '대머리 독수리'썰 | 스..
# https://tv.naver.com/v/12834372/list/67096
# 스톡킹
# https://tv.naver.com/mbc.sportstalking
# 다음 목록
# javascript:;
#
# https://tv.naver.com/sbs.2019taste
#
# https://channels.vlive.tv/CEB60F/home
# 추천 재생목록
# /recommend/playlist
#
#
#
#
#
#
#
#
# 🌸새봄맞이 포근하게 꾸며볼까~🔨
#
# 3분 전
#
#
#
# /playlist/576738
#
#
#
#
#
#
# 재생목록 항목 개수
# 재생목록
# 10
#
#
#
#
#
# /playlist/576612
# [2020.3.11] 10대 TOP10
# /playlist/576612
#
#
#
#
#
#
# 재생목록 항목 개수
# 재생목록
# 264
#
#
#
#
#
# /playlist/60927
# [분노] 야! 너 진짜 얌생이구나! 부글부글♨
# /playlist/60927
#
#
#
#
#
#
# 재생목록 항목 개수
# 재생목록
# 50
#
#
#
#
#
# /playlist/576745
# [2020.3.12] 챙겨보자! 네이버 메인에 뜬 영상들
# /playlist/576745
#
#
#
#
#
#
# 재생목록 항목 개수
# 재생목록
# 81
#
#
#
#
#
# /playlist/250202
# [입덕] 본격 입덕 가이드! 덕후 조련갑b
# /playlist/250202
#
#
#
#
#
# 재생시간1:10
#
#
# 천안 두정 효성해링턴 플레이스 아파트 시스템에어컨 공동구매
#
# 삼성LG시스템에어컨 더베스트솔루션
# 재생 수0
# 좋아요 수0
#
#
#
# https://tv.naver.com/v/12838314
# 나중에 보기
# #
#
#
#
# 재생시간2:57
#
# https://tv.naver.com/v/12838327
# 나중에 보기
# #
# “유럽에서 미국 오지 마!”…한국은 제한 해제 검토
# https://tv.naver.com/v/12838327
# KBS뉴스
# https://tv.naver.com/kbsnews
#
#
#
# 재생시간37:05
#
# https://tv.naver.com/v/12838311
# 나중에 보기
# #
# 고려대학교81 송년의밤[Korea University,高麗大學..
# https://tv.naver.com/v/12838311
# 대한부동산TV
# https://tv.naver.com/noinyung
#
#
#
# 재생시간0:55
#
# https://tv.naver.com/v/12838335
# 나중에 보기
# #
# 천안 두정 효성해링턴 플레이스 아파트 시스템에어..
# https://tv.naver.com/v/12838335
# 삼성LG시스템에어컨 더베스..
# https://tv.naver.com/thebest
#
#
#
# 재생시간0:50
#
# https://tv.naver.com/v/12838349
# 나중에 보기
# #
# 천안 두정 효성해링턴 플레이스 아파트 시스템에어..
# https://tv.naver.com/v/12838349
# 삼성LG시스템에어컨 더베스..
# https://tv.naver.com/thebest
#
#
#
#
# https://tv.naver.com/jtbcnews
# JTBC뉴스
# https://tv.naver.com/jtbcnews
#
#
#
#
# https://tv.naver.com/tvchosun.mistertrot
# 미스터트롯
# https://tv.naver.com/tvchosun.mistertrot
#
#
#
#
# https://tv.naver.com/tvchosun.wifetaste
# 아내의 맛
# https://tv.naver.com/tvchosun.wifetaste
#
#
#
#
# https://tv.naver.com/singlelife
# 나 혼자 산다
# https://tv.naver.com/singlelife
#
#
#
#
# https://tv.naver.com/kbs.beautiful
# 사랑은 뷰티풀 인생은 원더풀
# https://tv.naver.com/kbs.beautiful
#
#
#
#
# https://tv.naver.com/cjenm.HiByeMama
# 하이바이마마
# https://tv.naver.com/cjenm.HiByeMama
#
#
#
# 재생시간4:16
#
# https://tv.naver.com/v/12808751
# 나중에 보기
# #
# [MV] Glen Check_ Follow The White Rabbit
# https://tv.naver.com/v/12808751
# 1theK (원더케이)
# https://tv.naver.com/1thek
#
#
#
# 재생시간3:32
#
# https://tv.naver.com/v/12812824
# 나중에 보기
# #
# [놀이] 슈퍼잭과 함께 하는 컬러 색칠놀이 l 알록달록 ..
# https://tv.naver.com/v/12812824
# 꼬마히어로 슈퍼잭
# https://tv.naver.com/superzach
#
#
#
# 재생시간2:40
#
# https://tv.naver.com/v/12820505
# 나중에 보기
# #
# [UCL] '명실상부 에이스' 네이마르 도르트문..
# https://tv.naver.com/v/12820505
# SPORTSTIME (스포츠타임)
# https://tv.naver.com/spotvmaster
#
#
#
# 재생시간3:26
#
# https://tv.naver.com/v/12823071
# 나중에 보기
# #
# [연애세포 자극 모먼트] 기억 조작하게 만드는 해원♡은..
# https://tv.naver.com/v/12823071
# 날씨가 좋으면 찾아가겠어요
# https://tv.naver.com/jtbc.weatherfine
#
#
#
# 재생시간3:54
#
# https://tv.naver.com/v/12816466
# 나중에 보기
# #
# [풀버전] 장윤정을 울컥하게 만든 버스킹 ♬초혼♬
# https://tv.naver.com/v/12816466
# 트롯신이 떴다
# https://tv.naver.com/sbs.trotgod
#
#
#
# 재생시간8:56
#
# https://tv.naver.com/v/12718116
# 나중에 보기
# #
# 선택을 못하는 친구가 너무 답답해요 | 고민뿜뿜! 키즈 ..
# https://tv.naver.com/v/12718116
# 캐리와장난감친구들
# https://tv.naver.com/carrieandtoys
#
#
#
# 재생시간6:42
#
# https://tv.naver.com/v/12698756
# 나중에 보기
# #
# 결국 저도 수영장 문 닫았습니다...
# https://tv.naver.com/v/12698756
# YS스윔키즈 대표 김예슬 수..
# https://tv.naver.com/ysswim
#
#
#
# 재생시간1:49
#
# https://tv.naver.com/v/12816177
# 나중에 보기
# #
# 현실 육아에 지친 찐엄마 성연, 이대로 괜찮을까..?
# https://tv.naver.com/v/12816177
# 살림하는 남자들
# https://tv.naver.com/kbs.housekeeping
#
#
#
# 재생시간1:24
#
# https://tv.naver.com/v/12816083
# 나중에 보기
# #
# 모두가 살았다... 악에 받친 임주환에 옥택연 ＂내가 사..
# https://tv.naver.com/v/12816083
# 더게임:0시를 향하여
# https://tv.naver.com/mbc.thegame
#
#
#
# 재생시간3:16
#
# https://tv.naver.com/v/12811967
# 나중에 보기
# #
# ITZY(있지) "WANNABE" Dance Practice
# https://tv.naver.com/v/12811967
# JYPnation
# https://tv.naver.com/jypnation
#
#
#
# 재생시간8:20
#
# https://tv.naver.com/v/12811144
# 나중에 보기
# #
# 강성훈처럼 비거리 50야드 늘리기, 가능할까? ｜ 최경주 ..
# https://tv.naver.com/v/12811144
# 민학수의 올댓골프
# https://tv.naver.com/allthatgolf
#
#
#
# 재생시간14:47
#
# https://tv.naver.com/v/12794064
# 나중에 보기
# #
# DIY/ MINI BACKPACK ZIPPER POUCH/ MAKEUP POUCH/ 미니 ..
# https://tv.naver.com/v/12794064
# 텐더스마일 핸드메이드
# https://tv.naver.com/tendersmilehandmade
#
#
#
# 재생시간2:41
#
# https://tv.naver.com/v/12817844
# 나중에 보기
# #
# [진실 혹은 거짓] 코로나19는 날씨가 따뜻해지면 사라진..
# https://tv.naver.com/v/12817844
# 차이나는 클라스
# https://tv.naver.com/jtbc.jtbclecture
#
#
#
# 재생시간2:49
#
# https://tv.naver.com/v/12514717
# 나중에 보기
# #
# 장난감 고쳐보아요 | 베이비버스 동요
# https://tv.naver.com/v/12514717
# 베이비버스 인기동요 동화
# https://tv.naver.com/babybus
#
#
#
# 재생시간3:24
#
# https://tv.naver.com/v/12656990
# 나중에 보기
# #
# 드라이기 없이 머리빨리 말리는 꿀팁 ! 3분
# https://tv.naver.com/v/12656990
# 호피쏘피 바이브
# https://tv.naver.com/hopisophie
#
#
#
# 재생시간11:59
#
# https://tv.naver.com/v/12762004
# 나중에 보기
# #
# [랜선집들이] 인테리어 갑 홍대 미용실 투어 브이로그 ..
# https://tv.naver.com/v/12762004
# SOONSIKI
# https://tv.naver.com/soonsikihair
#
#
#
# 재생시간5:18
#
# https://tv.naver.com/v/12551087
# 나중에 보기
# #
# 곡예비행사 박쥐 | 박쥐의 특징 | 초음파로 길 찾기 | ..
# https://tv.naver.com/v/12551087
# 지니키즈 (인기 동요・동화・..
# https://tv.naver.com/genikids
#
#
#
# 재생시간3:27
#
# https://tv.naver.com/v/12802206
# 나중에 보기
# #
# [MV] 주니(JUNNY) _ By My Side
# https://tv.naver.com/v/12802206
# 1theK (원더케이)
# https://tv.naver.com/1thek
#
#
#
# 재생시간6:03
#
# https://tv.naver.com/v/12721581
# 나중에 보기
# #
# 1주일 다이어트 계획표✔로 면역력은 올리고, 잉여지방은..
# https://tv.naver.com/v/12721581
# 다이어트의 정석 - 다노TV
# https://tv.naver.com/danotv
#
#
#
# 재생시간4:06
#
# https://tv.naver.com/v/12801771
# 나중에 보기
# #
# [MV] Coda Bridge(코다브릿지) - How(내가 널 어떻게)
# https://tv.naver.com/v/12801771
# MUSIC&NEW
# https://tv.naver.com/musicnnew
#
#
#
# 재생시간3:20
#
# https://tv.naver.com/v/12770672
# 나중에 보기
# #
# 도와줘요 마스크맨 | 나쁜 세균 무찌르자! | 생활습관 ..
# https://tv.naver.com/v/12770672
# 티디키즈 by 지니키즈
# https://tv.naver.com/tidi
#
#
#
# 재생시간2:37
#
# https://tv.naver.com/v/12800086
# 나중에 보기
# #
# '열광하는 홈팬들' 전광석화 같은 자비처의 ..
# https://tv.naver.com/v/12800086
# SPOTV_UCL
# https://tv.naver.com/champsnv
#
#
#
# 재생시간10:45
#
# https://tv.naver.com/v/12803779
# 나중에 보기
# #
# [스페셜] 따뜻한 집이 필요한 우리 해원이.. '사랑..
# https://tv.naver.com/v/12803779
# 날씨가 좋으면 찾아가겠어요
# https://tv.naver.com/jtbc.weatherfine
#
#
#
# 재생시간3:37
#
# https://tv.naver.com/v/12792758
# 나중에 보기
# #
# [미방분] (나름)애교왕 이원일♥김유진 커플의 알콩달콩 ..
# https://tv.naver.com/v/12792758
# 부러우면 지는거다
# https://tv.naver.com/mbc.reallovestory
#
#
#
# 재생시간14:16
#
# https://tv.naver.com/v/12711433
# 나중에 보기
# #
# [문별] Eclipse Log #2 Moonstar Day
# https://tv.naver.com/v/12711433
# Rainbowbridge World
# https://tv.naver.com/rbw
#
#
#
# 재생시간24:00
#
# https://tv.naver.com/v/12670146
# 나중에 보기
# #
# 르노삼성 XM3 TCe260 (1.3 터보) 시승기 1부, 말해 뭐합..
# https://tv.naver.com/v/12670146
# 모터리언 Motorian
# https://tv.naver.com/nodikar
#
#
#
# 재생시간3:48
#
# https://tv.naver.com/v/12798902
# 나중에 보기
# #
# ‘새 친구’ 김형준, 다 같이 함께하는 맛있는 식사시간!
# https://tv.naver.com/v/12798902
# 불타는 청춘
# https://tv.naver.com/youngfire
#
#
#
# 재생시간4:18
#
# https://tv.naver.com/v/12788350
# 나중에 보기
# #
# [메이킹] 5G 속도 해원과 임뚝딱 군 '굿나잇 책방&..
# https://tv.naver.com/v/12788350
# 날씨가 좋으면 찾아가겠어요
# https://tv.naver.com/jtbc.weatherfine
#
#
#
# 재생시간2:55
#
# https://tv.naver.com/v/12769986
# 나중에 보기
# #
# [예능연구소 직캠] IZ*ONE - SPACESHIP(Choi Yena), 아..
# https://tv.naver.com/v/12769986
# MBC 예능연구소 직캠
# https://tv.naver.com/mbc.showmusiccorefancam
#
#
#
# 재생시간6:24
#
# https://tv.naver.com/v/12765908
# 나중에 보기
# #
# 11년만에 K리그로 돌아온 이청용, 그 시절 활약 다시보..
# https://tv.naver.com/v/12765908
# Talk about K LEAGUE
# https://tv.naver.com/talkaboutkleague
# 확인
# #
# 홈
# /
# TOP
# #
# 이용약관
# http://www.naver.com/rules/service.html
# 개인정보처리방침
# http://www.naver.com/rules/privacy.html
# 책임의 한계와 법적고지
# http://www.naver.com/rules/disclaimer.html
# 네이버TV 고객센터
# https://help.naver.com/support/alias/navertv/navertv_home-PC.naver
# 채널 만들기
# https://studio.tv.naver.com/join
# 네이버TV 운영정책
# /n/policy
#
#
#
# http://www.naver.com
# NAVER Corp.
# http://www.navercorp.com
