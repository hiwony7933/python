# %%
import pandas as pd
df = pd.read_csv('../data/seoul.csv')
print(df.head())
df.plot()
# Out:
# date  avg  min  max
# 0  1910-01-01 -5.2 -6.6  0.6
# 1  1910-01-02 -7.2 -9.4 -4.3
# 2  1910-01-03 -1.2 -8.2  3.4
# 3  1910-01-04  3.2  0.4  8.0
# 4  1910-01-05  2.5 -0.3  7.5
